# %%
from Convo2dModel import toothClassification

# %%
toothClassification()
# Out:
# Found 10 images belonging to 2 classes.
# Found 2 images belonging to 2 classes.
# Epoch 1/5
# ...
# 1/1 [==============================] - 0s 132ms/step
#  you are old
# 1/1 [==============================] - 0s 32ms/step
#  you are old
# 1/1 [==============================] - 0s 32ms/step
#  you are old
# 1/1 [==============================] - 0s 33ms/step
#  you are teen
